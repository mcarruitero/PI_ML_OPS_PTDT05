# %%
#Steam Games
#Importo Librerias
import pandas as pd
import re

# %%
#Asigno al DataFrame el archivo json steam_games.json.gz
#df_sg=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/steam_games.json.gz',compression='gzip',lines=True,encoding='utf-8')
df_sg=pd.read_json('./Dataset/steam_games.json.gz',compression='gzip',lines=True,encoding='utf-8')

# %%
#Elimino filas totalmente vacias
df_sg.dropna(how='all',inplace=True)

# %%
#Busqueda de Id nulos
df_sg[(df_sg['id'].isnull())]
# Out:
#                                                 publisher  \
# 88384                                                None
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 88384                  None                                            None
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 88384                                             None
# 119271  Batman: Arkham City - Game of the Year Edition
#
#                                              url release_date  \
# 88384             http://store.steampowered.com/         None
# 119271  http://store.steampowered.com/app/200260   2012-09-07
#
#                                                      tags reviews_url  \
# 88384                                                None        None
# ...

# %%
#Busqueda de aplicacion con similar nombre de Id nulo
df_sg[(df_sg['app_name'] == 'Batman: Arkham City - Game of the Year Edition')]
# Out:
#                                                 publisher  \
# 89378   Warner Bros. Interactive Entertainment, Feral ...
# 119271  Warner Bros. Interactive Entertainment, Feral ...
#
#                      genres                                        app_name  \
# 89378   [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
# 119271  [Action, Adventure]  Batman: Arkham City - Game of the Year Edition
#
#                                                  title  \
# 89378   Batman: Arkham City - Game of the Year Edition
# 119271  Batman: Arkham City - Game of the Year Edition
#
#                                                       url release_date  \
# 89378   http://store.steampowered.com/app/200260/Batma...   2012-09-07
# 119271           http://store.steampowered.com/app/200260   2012-09-07
#
#                                                      tags  \
# 89378   [Action, Open World, Batman, Adventure, Stealt...
# ...

# %%
#Eliminacion de id nulos
df_sg.dropna(subset=['id'],inplace=True)

# %%
#Duplicados
duplicados = df_sg['id'].value_counts() > 1
df_sg[df_sg['id'].isin(duplicados[duplicados].index)]
# Out:
#                  publisher    genres                          app_name  \
# 102204  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
# 102883  Bethesda Softworks  [Action]  Wolfenstein II: The New Colossus
#
#                                    title  \
# 102204  Wolfenstein II: The New Colossus
# 102883  Wolfenstein II: The New Colossus
#
#                                                       url release_date  \
# 102204          http://store.steampowered.com/app/612880/   2017-10-26
# 102883  http://store.steampowered.com/app/612880/Wolfe...   2017-10-26
#
#                                                      tags  \
# 102204  [Action, FPS, Gore, Violent, Alternate History...
# 102883  [Action, FPS, Gore, Violent, Alternate History...
#
#                                               reviews_url  \
# 102204  http://steamcommunity.com/app/612880/reviews/?...
# 102883  http://steamcommunity.com/app/612880/reviews/?...
#
# ...

# %%
#Eliminación de Duplicados
df_sg.drop_duplicates(subset=['id'],inplace=True)

# %%
#Elimino genres vacios
df_sg.dropna(subset=['genres'],inplace=True)

# %%
#Búsqueda de nombres de aplicaciones vacias
df_sg[df_sg['app_name'].isnull()]
# Out:
#       publisher           genres app_name title  \
# 90890      None  [Action, Indie]     None  None
#
#                                                url release_date  \
# 90890  http://store.steampowered.com/app/317160/_/   2014-08-26
#
#                   tags                                        reviews_url  \
# 90890  [Action, Indie]  http://steamcommunity.com/app/317160/reviews/?...
#
#                             specs price  early_access        id developer
# 90890  [Single-player, Game demo]  None           0.0  317160.0      None

# %%
#Eliminacion de aplicaciones vacias
df_sg.dropna(subset=['app_name'],inplace=True)

# %%
#Eliminacion de columnas no necesarias
df_sg = df_sg.drop(columns=['publisher','title','url','reviews_url','early_access','specs','tags','price','developer'])

# %%
#Validacion de columnas nulas
df_sg.isnull().sum()
# Out:
# genres           0
# app_name         0
# release_date    18
# id               0
# dtype: int64

# %%
#Eliminacion de release_date nulas
df_sg.dropna(subset=['release_date'],inplace=True)

# %%
#Filtro año de fechas correctas
import re

def filtrar_dataframe_formato_fecha(df, nombre_columna):
    # Definir el patron  regex 'YYYY-MM-DD'
    patron_fecha = re.compile(r'^\d{4}-\d{2}-\d{2}$')

    # Filtrar filas con el correcto formato de fecha
    mask = df[nombre_columna].astype(str).str.match(patron_fecha)
    df_filtrado = df[mask]

    return df_filtrado

df_sg = filtrar_dataframe_formato_fecha(df_sg, 'release_date')

# %%
# Convierto id a entero
df_sg['id'] = df_sg['id'].astype('int')

# %%
# Convierto fecha a Año
df_sg['release_date'] = pd.to_datetime(df_sg['release_date'], errors='coerce')
df_sg['release_date'] = df_sg['release_date'].dt.year

# %%
# Mover la columna 'id' al principio, renombrarla por item_id y cambiar el tipo a int
df_sg.columns.get_loc('id')
nuevas_columnas = ['id'] + [columna for columna in df_sg.columns if columna != 'id']
df_sg = df_sg[nuevas_columnas]
df_sg.rename(columns={'id': 'item_id'}, inplace=True)
df_sg['item_id'] = df_sg['item_id'].astype('int')
# Mostrar las primeras filas del DataFrame con 'id' en la primera posición
df_sg.head()
# Out:
#        item_id                                             genres  \
# 88310   761140      [Action, Casual, Indie, Simulation, Strategy]
# 88311   643980               [Free to Play, Indie, RPG, Strategy]
# 88312   670290  [Casual, Free to Play, Indie, Simulation, Sports]
# 88313   767400                        [Action, Adventure, Casual]
# 88315   772540                    [Action, Adventure, Simulation]
#
#                       app_name  release_date
# 88310      Lost Summoner Kitty          2018
# 88311                Ironbound          2018
# 88312  Real Pool 3D - Poolians          2017
# 88313                  弹炸人2222          2017
# 88315    Battle Royale Trainer          2018

# %%
#Desanidar genres y eliminar columna index
df_sg = df_sg.explode('genres').reset_index()
df_sg = df_sg.drop(columns="index")
df_sg.head()
# Out:
#    item_id      genres             app_name  release_date
# 0   761140      Action  Lost Summoner Kitty          2018
# 1   761140      Casual  Lost Summoner Kitty          2018
# 2   761140       Indie  Lost Summoner Kitty          2018
# 3   761140  Simulation  Lost Summoner Kitty          2018
# 4   761140    Strategy  Lost Summoner Kitty          2018

# %%
#Obtener generos unicos
df_generos_diferentes = df_sg['genres'].unique()
df_generos_diferentes.sort()

# %%
# Guardo Dataframe en csv
#df_sg.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_sg.csv',index=False)
df_sg.to_csv('./Dataset/df_sg.csv',index=False)

# %%
import ast
import gzip

# %%
# User_Items
List_User_Items = []
with gzip.open(u"/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/users_items.json.gz", 'rt', encoding='UTF-8') as f:
#with open("/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz", encoding='UTF-8') as f:
    for line in f.readlines():
        List_User_Items.append(ast.literal_eval(line))

df_ui = pd.DataFrame(List_User_Items)
df_ui = df_ui.explode('items').reset_index()
df_ui = df_ui.drop(columns="index")
df_ui = pd.concat([df_ui, pd.json_normalize(df_ui['items'])], axis=1)
df_ui = df_ui.drop(columns='items')

# %%
#
df_ui
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# ...

# %%
df_ui
#df_ui[df_ui['items_count'].max()]

max_items_count = df_ui['items_count'].max()
filtered_df = df_ui[df_ui['items_count'] == max_items_count]
min_items_count = df_ui['items_count'].min()
filtered_df
min_items_count
max_items_count

#df_ui[df_ui['user_id'].isnull()]
#df_ui[df_ui['items_count'].isna()]
#df_ui.isna()
#df_ui[df_ui['user_id'].isna()]

#df_ui.isnull().sum()
#df_ui[df_ui['item_id'].isna()]
# Out:
# 7762

# %%
#df_ui
#df_ui1['items'][0]#[0]
#df_ui.isnull().sum()
#df_ui.info()
#df_ui.describe()
df_ui[df_ui['item_id'].isna()]
#df_ui[df_ui['playtime_forever'].isna()]
#df_ui
#df_ui[df_ui['playtime_forever'].isnull()]
#df_ui.isnull()
# Out:
#                          user_id  items_count           steam_id  \
# 3733                      Wackky            0  76561198039117046
# 3849           76561198079601835            0  76561198079601835
# 6019                    hellom8o            0  76561198117222320
# 6523         starkillershadow553            0  76561198059648579
# 7237                  darkenkane            0  76561198058876001
# ...                          ...          ...                ...
# 5169470        76561198316380182            0  76561198316380182
# 5169471        76561198316970597            0  76561198316970597
# 5169472        76561198318100691            0  76561198318100691
# 5170006  XxLaughingJackClown77xX            0  76561198328759259
# 5170014        edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id item_name  \
# 3733                   http://steamcommunity.com/id/Wackky     NaN       NaN
# ...

# %%
df_ui[df_ui['user_id']=='76561197970982479']
#df_ui[df_ui['user_id']=='76561198329548331']
# Out:
#                user_id  items_count           steam_id  \
# 0    76561197970982479          277  76561197970982479
# 1    76561197970982479          277  76561197970982479
# 2    76561197970982479          277  76561197970982479
# 3    76561197970982479          277  76561197970982479
# 4    76561197970982479          277  76561197970982479
# ..                 ...          ...                ...
# 272  76561197970982479          277  76561197970982479
# 273  76561197970982479          277  76561197970982479
# 274  76561197970982479          277  76561197970982479
# 275  76561197970982479          277  76561197970982479
# 276  76561197970982479          277  76561197970982479
#
#                                               user_url item_id  \
# 0    http://steamcommunity.com/profiles/76561197970...      10
# 1    http://steamcommunity.com/profiles/76561197970...      20
# 2    http://steamcommunity.com/profiles/76561197970...      30
# ...

# %%
# Elimino Vacios
df_ui.dropna(inplace=True)

# %%
#df_ui=df_ui.reset_index()

# %%
df_ui
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170009  76561198329548331            7  76561198329548331
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# ...

# %%
#
df_ui.isnull().sum()
# Out:
# user_id             0
# items_count         0
# steam_id            0
# user_url            0
# item_id             0
# item_name           0
# playtime_forever    0
# playtime_2weeks     0
# dtype: int64

# %%
# Elimino columnas
#df_ui = df_ui.drop(columns=['items_count','steam_id','user_url','item_name','playtime_2weeks'],inplace=True)
#df_ui.drop(columns=['items_count','steam_id','user_url','item_name','playtime_2weeks'],inplace=True)
df_ui.drop(columns=['items_count','steam_id','user_url','playtime_2weeks'],inplace=True)

# %%
df_ui
# Out:
#                    user_id item_id                      item_name  \
# 0        76561197970982479      10                 Counter-Strike
# 1        76561197970982479      20          Team Fortress Classic
# 2        76561197970982479      30                  Day of Defeat
# 3        76561197970982479      40             Deathmatch Classic
# 4        76561197970982479      50      Half-Life: Opposing Force
# ...                    ...     ...                            ...
# 5170009  76561198329548331  346330                   BrainBread 2
# 5170010  76561198329548331  373330                    All Is Dust
# 5170011  76561198329548331  388490  One Way To Die: Steam Edition
# 5170012  76561198329548331  521570          You Have 10 Seconds 2
# 5170013  76561198329548331  519140                     Minds Eyes
#
#          playtime_forever
# 0                     6.0
# 1                     0.0
# 2                     7.0
# 3                     0.0
# 4                     0.0
# ...

# %%
#df_ui.reset_index()
df_ui.reset_index(drop=True, inplace=True)

# %%
#
df_ui
# Out:
#                    user_id item_id                      item_name  \
# 0        76561197970982479      10                 Counter-Strike
# 1        76561197970982479      20          Team Fortress Classic
# 2        76561197970982479      30                  Day of Defeat
# 3        76561197970982479      40             Deathmatch Classic
# 4        76561197970982479      50      Half-Life: Opposing Force
# ...                    ...     ...                            ...
# 5153204  76561198329548331  346330                   BrainBread 2
# 5153205  76561198329548331  373330                    All Is Dust
# 5153206  76561198329548331  388490  One Way To Die: Steam Edition
# 5153207  76561198329548331  521570          You Have 10 Seconds 2
# 5153208  76561198329548331  519140                     Minds Eyes
#
#          playtime_forever
# 0                     6.0
# 1                     0.0
# 2                     7.0
# 3                     0.0
# 4                     0.0
# ...

# %%
#df_ui = df_ui.drop(columns=['index'])
# Convierto id a entero
df_ui['playtime_forever'] = df_ui['playtime_forever'].astype('int')
df_ui['item_id'] = df_ui['item_id'].astype('int')

# %%
#
df_ui
# Out:
#                    user_id  item_id                      item_name  \
# 0        76561197970982479       10                 Counter-Strike
# 1        76561197970982479       20          Team Fortress Classic
# 2        76561197970982479       30                  Day of Defeat
# 3        76561197970982479       40             Deathmatch Classic
# 4        76561197970982479       50      Half-Life: Opposing Force
# ...                    ...      ...                            ...
# 5153204  76561198329548331   346330                   BrainBread 2
# 5153205  76561198329548331   373330                    All Is Dust
# 5153206  76561198329548331   388490  One Way To Die: Steam Edition
# 5153207  76561198329548331   521570          You Have 10 Seconds 2
# 5153208  76561198329548331   519140                     Minds Eyes
#
#          playtime_forever
# 0                       6
# 1                       0
# 2                       7
# 3                       0
# ...

# %%
df_sg
# Out:
#         item_id      genres             app_name  release_date
# 0      761140.0      Action  Lost Summoner Kitty          2018
# 1      761140.0      Casual  Lost Summoner Kitty          2018
# 2      761140.0       Indie  Lost Summoner Kitty          2018
# 3      761140.0  Simulation  Lost Summoner Kitty          2018
# 4      761140.0    Strategy  Lost Summoner Kitty          2018
# ...         ...         ...                  ...           ...
# 70694  610660.0       Indie        Russian Roads          2018
# 70695  610660.0      Racing        Russian Roads          2018
# 70696  610660.0  Simulation        Russian Roads          2018
# 70697  658870.0      Casual  EXIT 2 - Directions          2017
# 70698  658870.0       Indie  EXIT 2 - Directions          2017
#
# [70699 rows x 4 columns]

# %%
#
df_sg[df_sg['item_id']==610660]
df_sg[df_sg['item_id']==10]
#df_sg[(df_sg['item_name'] == 'Counter-Strike')]
# Out:
#        item_id  genres        app_name  release_date
# 70651       10  Action  Counter-Strike          2000

# %%
#
df_ui[df_ui['item_id']==10]
#df_ui[(df_ui['item_name'] == 'Counter-Strike')]
#df_ui['item_id'] = df_ui['item_id'].astype('int')
#df_ui['playtime_forever'] = df_ui['playtime_forever'].astype('int')
#df_ui.reset_index()
# Out:
#                    user_id  item_id  playtime_forever
# 0        76561197970982479       10                 6
# 277                js41637       10                 0
# 1302            Riot-Punch       10                 0
# 1635                 doctr       10                93
# 3737        corrupted_soul       10               108
# ...                    ...      ...               ...
# 5150423  76561198273508956       10                21
# 5150611  76561198282090798       10                 1
# 5150664             943525       10                 0
# 5150692  76561198283312749       10                 6
# 5152606  76561198312638244       10                 0
#
# [9735 rows x 3 columns]

# %%
#
df_ui
# Out:
#                    user_id  item_id                      item_name  \
# 0        76561197970982479       10                 Counter-Strike
# 1        76561197970982479       20          Team Fortress Classic
# 2        76561197970982479       30                  Day of Defeat
# 3        76561197970982479       40             Deathmatch Classic
# 4        76561197970982479       50      Half-Life: Opposing Force
# ...                    ...      ...                            ...
# 5153204  76561198329548331   346330                   BrainBread 2
# 5153205  76561198329548331   373330                    All Is Dust
# 5153206  76561198329548331   388490  One Way To Die: Steam Edition
# 5153207  76561198329548331   521570          You Have 10 Seconds 2
# 5153208  76561198329548331   519140                     Minds Eyes
#
#          playtime_forever
# 0                       6
# 1                       0
# 2                       7
# 3                       0
# ...

# %%
df_ui.drop(df_ui[df_ui['playtime_forever'] == 0].index, inplace=True)
df_ui.reset_index(drop=True, inplace=True)

#df_ui = df_ui[df_ui['playtime_forever'] != '0.0']
#df_ui.drop(df_ui[df_ui['playtime_forever'] == '0.0'].index, inplace=True)
#df.drop(df[df['column_name'] == 0].index, inplace=True)

# %%
#
df_ui
# Out:
#                    user_id  item_id                      item_name  \
# 0        76561197970982479       10                 Counter-Strike
# 1        76561197970982479       30                  Day of Defeat
# 2        76561197970982479      300          Day of Defeat: Source
# 3        76561197970982479      240         Counter-Strike: Source
# 4        76561197970982479     3830                    Psychonauts
# ...                    ...      ...                            ...
# 3285241  76561198329548331   304930                       Unturned
# 3285242  76561198329548331   227940              Heroes & Generals
# 3285243  76561198329548331   388490  One Way To Die: Steam Edition
# 3285244  76561198329548331   521570          You Have 10 Seconds 2
# 3285245  76561198329548331   519140                     Minds Eyes
#
#          playtime_forever
# 0                       6
# 1                       7
# 2                    4733
# 3                    1853
# ...

# %%
#df_ui_csv = df_ui.reset_index(drop=True)
result_df = df_ui.groupby('item_id')['playtime_forever'].sum().reset_index()

# %%
#df_ui_csv

# %%
# Guardo Dataframe en csv comprimido
df_ui.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_ui.csv.gz',index=False, compression='gzip')
#df.to_csv(compressed_file_path, index=False, compression='gzip')

# %%
#Crear archivo base de genres
df_sgui=pd.merge(df_sg[['item_id','genres','release_date']],df_ui[['item_id','playtime_forever']],on='item_id',how='left')

#df_ug=pd.merge(df_sg[['genres','release_date']],df_ui[['playtime_forever']],on='item_id',how='left')
#df_sgui
#df_ug[df_ug['item_id']==10]

# hago un merge teniendo todos los usuarios
#user_rev_item = pd.merge(user_items_proc[['user_id','item_id','playtime_forever']],user_review[['user_id','recommend']],on = 'user_id',how='left')
# Me quedo solo con los que estan nulos en reviews
#user_rev_item = user_rev_item[user_rev_item['recommend'].isnull()]
# Hago un agrupamiento por usuario y saco el id del que tiene mas minuntos.
#max_playtime_items = user_rev_item.groupby('user_id')['playtime_forever'].idxmax()
#result_df = user_rev_item.loc[max_playtime_items, ['user_id', 'item_id']]
#result_df.to_csv('../datasets/user_item_max_horas.csv',index=False) # Exporto para ser usado por la funcion

# %%
#
df_sgui
# Out:
#           item_id      genres  release_date  playtime_forever
# 0        761140.0      Action          2018               NaN
# 1        761140.0      Casual          2018               NaN
# 2        761140.0       Indie          2018               NaN
# 3        761140.0  Simulation          2018               NaN
# 4        761140.0    Strategy          2018               NaN
# ...           ...         ...           ...               ...
# 6926973  610660.0       Indie          2018               NaN
# 6926974  610660.0      Racing          2018               NaN
# 6926975  610660.0  Simulation          2018               NaN
# 6926976  658870.0      Casual          2017               NaN
# 6926977  658870.0       Indie          2017               NaN
#
# [6926978 rows x 4 columns]

# %%
df_sgui.dropna(inplace=True)

# %%
df_sgui
# Out:
#           item_id  genres  release_date  playtime_forever
# 75       282010.0  Action          1997               5.0
# 76       282010.0  Action          1997              13.0
# 77       282010.0  Action          1997             110.0
# 78       282010.0  Action          1997              13.0
# 79       282010.0  Action          1997               8.0
# ...           ...     ...           ...               ...
# 6926945      80.0  Action          2004             203.0
# 6926946      80.0  Action          2004             244.0
# 6926947      80.0  Action          2004               7.0
# 6926948      80.0  Action          2004               9.0
# 6926949      80.0  Action          2004              99.0
#
# [6876307 rows x 4 columns]

# %%
df_sgui.isnull().sum()
# Out:
# item_id             0
# genres              0
# release_date        0
# playtime_forever    0
# dtype: int64

# %%
df_PlayTimeGenre = df_sgui.groupby(['genres', 'release_date'])['playtime_forever'].sum().reset_index()

# %%
df_PlayTimeGenre
# Out:
#              genres  release_date  playtime_forever
# 0            Action          1983            3582.0
# 1            Action          1984             384.0
# 2            Action          1988           16243.0
# 3            Action          1989             607.0
# 4            Action          1990           18787.0
# ..              ...           ...               ...
# 335  Web Publishing          2013          335849.0
# 336  Web Publishing          2014           33732.0
# 337  Web Publishing          2015          348861.0
# 338  Web Publishing          2016             136.0
# 339  Web Publishing          2017            9713.0
#
# [340 rows x 3 columns]

# %%
df_PlayTimeGenre.isnull().sum()
# Out:
# genres              0
# release_date        0
# playtime_forever    0
# dtype: int64

# %%
#df_ui.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv',index=False)
df_PlayTimeGenre.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv',index=False)

# %%
#Funcion PlayTimeGenre
genre='RPG'
df_playtimegenre= pd.read_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv')
#df_playtimegenre.head
#df_playtimegenre
df_filtered_by_genre = df_playtimegenre[df_playtimegenre['genres'] == genre]
gender_hours = df_filtered_by_genre.groupby('release_date')['playtime_forever'].sum()
max_time_play_gender = gender_hours.idxmax()
result = {
  "Año de lanzamiento con más horas jugadas para Género {}".format(genre) : max_time_play_gender
  }
result
# Out:
# {'Año de lanzamiento con más horas jugadas para Género RPG': 2011}

# %%
#df_ui.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv',index=False)
#df_PlayTimeGenre.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv',index=False)

# %%
df_generos_diferentes = df_sg['genres'].unique()
df_generos_diferentes.sort()
for genero in df_generos_diferentes:
  print(genero)
# Out:
# Accounting
# Action
# Adventure
# Animation &amp; Modeling
# Audio Production
# Casual
# Design &amp; Illustration
# Early Access
# Education
# Free to Play
# Indie
# Massively Multiplayer
# Photo Editing
# RPG
# Racing
# Simulation
# Software Training
# Sports
# Strategy
# Utilities
# Video Production
# Web Publishing

# %%
#gener_user = pd.merge(df_ui[['item_id','playtime_forever','user_id']],df_sg,left_on='item_id',right_on='id',how='inner')
#df_sgui_gu=pd.merge(df_sg[['item_id','genres','release_date']],df_ui[['item_id','playtime_forever','user_id']],on='item_id',how='left')
df_sgui_gu=pd.merge(df_sg[['item_id','genres','release_date']],df_ui[['item_id','playtime_forever','user_id']],on='item_id',how='left')
df_sgui_gu.dropna(inplace=True)

usuario_por_genero = []
df_UserForGenre = pd.DataFrame(columns=['user_id', 'genres', 'release_date', 'playtime_forever'])

for genero in df_generos_diferentes:
    # Filtramos las filas del género actual
    df_genero = df_sgui_gu[df_sgui_gu['genres'] == genero]
    # Filtramos el usuario del género actual
    if not df_genero.empty:
        # Filtramos al usuario con mayor 'playtime_forever' del género actual
        df_usuario = df_genero.groupby('user_id')['playtime_forever'].sum().idxmax()
        # Agrupamos los datos por usuario, genero y año y calculamos la suma de 'playtime_forever'
        df_usuario_genero_año = df_genero[df_genero['user_id'] == df_usuario].groupby(['user_id','genres', 'release_date'])['playtime_forever'].sum().reset_index()
        # Agregamos el df_usuario_genero_año a la lista usuario_por_genero
        usuario_por_genero.append(df_usuario_genero_año)
    else:
        pass
# Convertimos los resultados en un DataFrame
for df in usuario_por_genero:
    # Agregamos al DataFrame df_UserForGenre los dataframes de cada genero y usuario
    df_UserForGenre = pd.concat([df_UserForGenre, df], ignore_index=True)
df_UserForGenre
# Out:
#                user_id            genres release_date  playtime_forever
# 0              Sp3ctre            Action         1995             217.0
# 1              Sp3ctre            Action         1999              44.0
# 2              Sp3ctre            Action         2000           70644.0
# 3              Sp3ctre            Action         2001              13.0
# 4              Sp3ctre            Action         2002             238.0
# ..                 ...               ...          ...               ...
# 134  76561198073642113         Utilities         2014          207651.0
# 135         ScottyG555  Video Production         2015          168314.0
# 136            Xyphien    Web Publishing         2005            7296.0
# 137            Xyphien    Web Publishing         2012           64657.0
# 138            Xyphien    Web Publishing         2015           71011.0
#
# [139 rows x 4 columns]

# %%
df_UserForGenre.isnull().sum()
# Out:
# user_id             0
# genres              0
# release_date        0
# playtime_forever    0
# dtype: int64

# %%
df_UserForGenre.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_UserForGenre.csv',index=False)

# %%
#Funcion UserForGenre
genre='Action'
df_userforgenre= pd.read_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_UserForGenre.csv')
df_filtered_by_genre = df_userforgenre[df_userforgenre['genres']==genre]

user_hours = df_filtered_by_genre.groupby('user_id')['playtime_forever'].sum()
max_time_play_user = user_hours.idxmax()

max_user_df = df_filtered_by_genre[df_filtered_by_genre['user_id'] == max_time_play_user]
hours_by_year = max_user_df.groupby('release_date')['playtime_forever'].sum().reset_index()
hours_years_list = [
    {'Año':year, 'Horas': hours} for year, hours in zip(hours_by_year['release_date'],hours_by_year['playtime_forever'])
                    ]
result = {
  'Usuario con más horas jugadas para genero {}'.format(genre):max_time_play_user,
  'Horas jugadas': hours_years_list
  }
result
# Out:
# {'Usuario con más horas jugadas para genero Action': 'Sp3ctre',
#  'Horas jugadas': [{'Año': 1995, 'Horas': 217.0},
#   {'Año': 1999, 'Horas': 44.0},
#   {'Año': 2000, 'Horas': 70644.0},
#   {'Año': 2001, 'Horas': 13.0},
#   {'Año': 2002, 'Horas': 238.0},
#   {'Año': 2003, 'Horas': 7673.0},
#   {'Año': 2004, 'Horas': 127411.0},
#   {'Año': 2005, 'Horas': 21339.0},
#   {'Año': 2006, 'Horas': 896.0},
#   {'Año': 2007, 'Horas': 112784.0},
#   {'Año': 2008, 'Horas': 224.0},
#   {'Año': 2009, 'Horas': 108326.0},
#   {'Año': 2010, 'Horas': 78083.0},
#   {'Año': 2011, 'Horas': 154896.0},
#   {'Año': 2012, 'Horas': 378296.0},
#   {'Año': 2013, 'Horas': 120461.0},
#   {'Año': 2014, 'Horas': 130691.0},
#   {'Año': 2015, 'Horas': 307511.0},
#   {'Año': 2016, 'Horas': 29576.0},
#   {'Año': 2017, 'Horas': 43327.0}]}

# %%
df_generos_diferentes = df_sg['genres'].unique()
df_generos_diferentes.sort()
for genero in df_generos_diferentes:
  print(genero)
# Out:
# Accounting
# Action
# Adventure
# Animation &amp; Modeling
# Audio Production
# Casual
# Design &amp; Illustration
# Early Access
# Education
# Free to Play
# Indie
# Massively Multiplayer
# Photo Editing
# RPG
# Racing
# Simulation
# Software Training
# Sports
# Strategy
# Utilities
# Video Production
# Web Publishing

# %%
#FuncionUserforGenre
# %%writefile Funciones.py

#Importan librerias.
#import pandas as pd from pandas.core.groupby.generic
import pandas as pd
#import generate_property
#import pandas as pd

## Año con más horas jugadas por genero ##

# Leer el DataFrame df_games desde un archivo CSV
df_userforgenre= pd.read_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_PlayTimeGenre.csv')

def PlayTimeGenre(genre: str):
  df_filtered_by_genre = df_userforgenre[df_userforgenre['genres']==genre]
  gender_hours = df_filtered_by_genre.groupby('release_date')['playtime_forever'].sum()
  max_time_play_gender = gender_hours.idxlsmax()
  result = {
    "Año de lanzamiento con más horas jugadas para Género {}".format(genre) : max_time_play_gender
    }
  return result

PlayTimeGenre('Action')
# Out:
# Overwriting Funciones.py

# %%
# !python Funciones.py

# %%
# !pwd
# Out:
# /content

# %%
# Import your custom Python script
from Funciones import PlayTimeGenre


# Specify the file path in your Google Drive
#file_path = '/content/drive/My Drive/my_data/my_file.csv'

# Use the function to load the CSV file
#df = load_csv_file(file_path)

# Display the DataFrame
#print(df)
# Out:
#   File "<ipython-input-83-725deebfaaee>", line 2
#     from content/Funciones import PlayTimeGenre
#                 ^
# SyntaxError: invalid syntax

# %%
df_ui_ptg = df_ui.drop(columns=['item_id'])
#df_ui_ptg = df_ui_ptg.groupby('genres','release_date')['playtime_forever'].sum()
#df_ui_ptg = df_ui_ptg[df_ui_ptg['column_name'] != 0]


#df_ui_ptg = df_ug.drop(columns=['item_id'])
#df_ui_ptg
#df_ui_ptg = df_ui_ptg.groupby(['genres', 'release_date'])['playtime_forever'].sum().reset_index()
#df_ui_ptg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d1425eaedf05> in <cell line: 4>()
#       2 #df_ui_ptg = df_ui_ptg.groupby('genres','release_date')['playtime_forever'].sum()
#       3 #df_ui_ptg = df_ug.drop(columns=['item_id'])
# ----> 4 df_ui_ptg
#       5 #df_ui_ptg = df_ui_ptg.groupby(['genres', 'release_date'])['playtime_forever'].sum().reset_index()
#       6 #df_ui_ptg
#
# NameError: name 'df_ui_ptg' is not defined

# %%
#
df_ui[df_ui['item_id']==10]
# Out:
#                    user_id  items_count  item_id       item_name  \
# 0        76561197970982479          277       10  Counter-Strike
# 277                js41637          888       10  Counter-Strike
# 1302            Riot-Punch          328       10  Counter-Strike
# 1635                 doctr          541       10  Counter-Strike
# 3737        corrupted_soul          115       10  Counter-Strike
# ...                    ...          ...      ...             ...
# 5150423  76561198273508956           15       10  Counter-Strike
# 5150611  76561198282090798            5       10  Counter-Strike
# 5150664             943525           58       10  Counter-Strike
# 5150692  76561198283312749           49       10  Counter-Strike
# 5152606  76561198312638244           36       10  Counter-Strike
#
#          playtime_forever
# 0                     6.0
# 277                   0.0
# 1302                  0.0
# 1635                 93.0
# 3737                108.0
# ...

# %%
# Reviews
Reviews = []
with gzip.open(u"/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz", 'rt', encoding='UTF-8') as f:
#with open("/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz", encoding='UTF-8') as f:
    for line in f.readlines():
        Reviews.append(ast.literal_eval(line))

df_ur = pd.DataFrame(Reviews)
df_ur
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#Usamos ast.literal_eval para convertir cada línea en un diccionario y lo agregamos a la lista filas.
user_reviews_gz = "/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz"
filas=[]
with gzip.open(user_reviews_gz, 'rt', encoding='MacRoman') as archivo:
    for line in archivo.readlines():
        filas.append(ast.literal_eval(line))

df_ur = pd.DataFrame(filas)
df_ur
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#
#df_ur_explode = df_ur.explode('reviews') # Duplico las filas generando un diccionario por cada dicc#ionario en la lista
#df_ur_explode
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 1                js41637               http://steamcommunity.com/id/js41637
# ...                  ...                                                ...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
user_review_explode = df_ur.explode('reviews') # Duplico las filas generando un diccionario por cada dicc#ionario en la lista
# Ahora concateno el dataframe original, con el dataframe generado a partir de transformar los diccionarios a pandas
user_review_explode = pd.concat([user_review_explode.drop(['reviews'],axis=1),user_review_explode['reviews'].apply(pd.Series)],axis=1).reset_index()

# %%
#
#df_ur_explode
user_review_explode
# Out:
#        index            user_id  \
# 0          0  76561197970982479
# 1          0  76561197970982479
# 2          0  76561197970982479
# 3          1            js41637
# 4          1            js41637
# ...      ...                ...
# 59328  25797  76561198312638244
# 59329  25797  76561198312638244
# 59330  25798        LydiaMorley
# 59331  25798        LydiaMorley
# 59332  25798        LydiaMorley
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1      http://steamcommunity.com/profiles/76561197970...
# 2      http://steamcommunity.com/profiles/76561197970...
# 3                   http://steamcommunity.com/id/js41637
# 4                   http://steamcommunity.com/id/js41637
# ...                                                  ...
# 59328  http://steamcommunity.com/profiles/76561198312...
# 59329  http://steamcommunity.com/profiles/76561198312...
# ...

# %%
user_review_explode[user_review_explode['user_id']=='76561197970982479']
# Out:
#              user_id                                           user_url funny  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
#
#                      posted last_edited item_id         helpful recommend  \
# 0  Posted November 5, 2011.                1250  No ratings yet      True
# 0     Posted July 15, 2011.               22200  No ratings yet      True
# 0    Posted April 21, 2011.               43110  No ratings yet      True
#
#                                               review   0
# 0  Simple yet with great replayability. In my opi... NaN
# 0               It's unique and worth a playthrough. NaN
# 0  Great atmosphere. The gunplay can be a bit chu... NaN

# %%
#Elimino columnas
user_review_explode.drop(columns=['user_url','funny','helpful','last_edited',0],inplace=True)

# %%
user_review_explode.drop(columns=['index'],inplace=True)

# %%
#
user_review_explode
# Out:
#                  user_id                     posted item_id recommend  \
# 0      76561197970982479   Posted November 5, 2011.    1250      True
# 1      76561197970982479      Posted July 15, 2011.   22200      True
# 2      76561197970982479     Posted April 21, 2011.   43110      True
# 3                js41637      Posted June 24, 2014.  251610      True
# 4                js41637  Posted September 8, 2013.  227300      True
# ...                  ...                        ...     ...       ...
# 59328  76561198312638244            Posted July 10.      70      True
# 59329  76561198312638244             Posted July 8.  362890      True
# 59330        LydiaMorley             Posted July 3.  273110      True
# 59331        LydiaMorley            Posted July 20.     730      True
# 59332        LydiaMorley             Posted July 2.     440      True
#
#                                                   review
# 0      Simple yet with great replayability. In my opi...
# ...

# %%
from textblob import TextBlob
#import pandas as pd

# Assuming user_review_explode is your DataFrame, and 'reviews' is the column containing the text reviews
user_review_explode['sentiment_analysis'] = user_review_explode['review'].apply(lambda x: TextBlob(str(x)).sentiment.polarity)

# Map sentiment scores to the specified scale (0 for bad, 1 for neutral, and 2 for positive)
user_review_explode['sentiment_analysis'] = user_review_explode['sentiment_analysis'].map(lambda x: 0 if x < 0 else (1 if x == 0 else 2))

# %%
#
user_review_explode
# Out:
#                  user_id                     posted item_id recommend  \
# 0      76561197970982479   Posted November 5, 2011.    1250      True
# 1      76561197970982479      Posted July 15, 2011.   22200      True
# 2      76561197970982479     Posted April 21, 2011.   43110      True
# 3                js41637      Posted June 24, 2014.  251610      True
# 4                js41637  Posted September 8, 2013.  227300      True
# ...                  ...                        ...     ...       ...
# 59328  76561198312638244            Posted July 10.      70      True
# 59329  76561198312638244             Posted July 8.  362890      True
# 59330        LydiaMorley             Posted July 3.  273110      True
# 59331        LydiaMorley            Posted July 20.     730      True
# 59332        LydiaMorley             Posted July 2.     440      True
#
#                                                   review  sentiment_analysis
# ...

# %%
#
user_review_explode.isnull().sum()
# Out:
# user_id                0
# posted                28
# item_id               28
# recommend             28
# review                28
# sentiment_analysis     0
# dtype: int64

# %%
#
user_review_explode[user_review_explode.isnull().any(axis=1)]
# Out:
#                  user_id posted item_id recommend review  sentiment_analysis
# 137                gdxsd    NaN     NaN       NaN    NaN                   1
# 177    76561198094224872    NaN     NaN       NaN    NaN                   1
# 2559   76561198021575394    NaN     NaN       NaN    NaN                   1
# 10080            cmuir37    NaN     NaN       NaN    NaN                   1
# 13767          Jaysteeny    NaN     NaN       NaN    NaN                   1
# 15493             ML8989    NaN     NaN       NaN    NaN                   1
# 19184  76561198079215291    NaN     NaN       NaN    NaN                   1
# 20223  76561198079342142    NaN     NaN       NaN    NaN                   1
# 25056  76561198061996985    NaN     NaN       NaN    NaN                   1
# 26257  76561198108286351    NaN     NaN       NaN    NaN                   1
# 26674     CallTripleZero    NaN     NaN       NaN    NaN                   1
# ...

# %%
#
user_review_explode.dropna(inplace=True)

# %%
user_review_explode
# Out:
#                  user_id                     posted item_id recommend  \
# 0      76561197970982479   Posted November 5, 2011.    1250      True
# 1      76561197970982479      Posted July 15, 2011.   22200      True
# 2      76561197970982479     Posted April 21, 2011.   43110      True
# 3                js41637      Posted June 24, 2014.  251610      True
# 4                js41637  Posted September 8, 2013.  227300      True
# ...                  ...                        ...     ...       ...
# 59328  76561198312638244            Posted July 10.      70      True
# 59329  76561198312638244             Posted July 8.  362890      True
# 59330        LydiaMorley             Posted July 3.  273110      True
# 59331        LydiaMorley            Posted July 20.     730      True
# 59332        LydiaMorley             Posted July 2.     440      True
#
#                                                   review  sentiment_analysis
# ...

# %%
user_review_explode[user_review_explode['sentiment_analysis']==2]
# Out:
#        index            user_id                    posted item_id recommend  \
# 0          0  76561197970982479  Posted November 5, 2011.    1250      True
# 1          0  76561197970982479     Posted July 15, 2011.   22200      True
# 2          0  76561197970982479    Posted April 21, 2011.   43110      True
# 3          1            js41637     Posted June 24, 2014.  251610      True
# 6          2          evcentric        Posted February 3.  248820      True
# ...      ...                ...                       ...     ...       ...
# 59328  25797  76561198312638244           Posted July 10.      70      True
# 59329  25797  76561198312638244            Posted July 8.  362890      True
# 59330  25798        LydiaMorley            Posted July 3.  273110      True
# 59331  25798        LydiaMorley           Posted July 20.     730      True
# 59332  25798        LydiaMorley            Posted July 2.     440      True
#
# ...

# %%
#
#user_review_explode.to_csv('../datasets/df_ur.csv',index=False)
user_review_explode.to_csv('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/df_ur.csv',index=False)

# %%
# def PlayTimeGenre( genero : str ):
df_sg
# Out:
#        item_id      genres             app_name  release_date
# 0       761140      Action  Lost Summoner Kitty          2018
# 1       761140      Casual  Lost Summoner Kitty          2018
# 2       761140       Indie  Lost Summoner Kitty          2018
# 3       761140  Simulation  Lost Summoner Kitty          2018
# 4       761140    Strategy  Lost Summoner Kitty          2018
# ...        ...         ...                  ...           ...
# 70694   610660       Indie        Russian Roads          2018
# 70695   610660      Racing        Russian Roads          2018
# 70696   610660  Simulation        Russian Roads          2018
# 70697   658870      Casual  EXIT 2 - Directions          2017
# 70698   658870       Indie  EXIT 2 - Directions          2017
#
# [70699 rows x 4 columns]

# %%
#
#user_review_explode = df_ur.explode('reviews') # Duplico las filas generando un diccionario por cada dicc#ionario en la lista
#user_review_explode
#df_ur['reviews'][0][76561197970982479	]
# Ahora concateno el dataframe original, con el dataframe generado a partir de transformar los diccionarios a pandas
#user_review_explode = pd.concat([user_review_explode.drop(['reviews'],axis=1),user_review_explode['reviews'].apply(pd.Series)],axis=1)

df_ur['user_id'][0][0][0]
# Out:
# 0    76561197970982479
# 0    76561197970982479
# 0    76561197970982479
# Name: user_id, dtype: object

# %%
 # hago un merge teniendo todos los usuarios
user_rev_item = pd.merge(df_ui[['user_id','item_id','playtime_forever']],user_review[['user_id','recommend']],on = 'user_id',how='left')
# Me quedo solo con los que estan nulos en reviews
user_rev_item = user_rev_item[user_rev_item['recommend'].isnull()]
# Hago un agrupamiento por usuario y saco el id del que tiene mas minuntos.
max_playtime_items = user_rev_item.groupby('user_id')['playtime_forever'].idxmax()
result_df = user_rev_item.loc[max_playtime_items, ['user_id', 'item_id']]
result_df.to_csv('../datasets/user_item_max_horas.csv',index=False) # Exporto para ser usado por la funcion

# %%
def verify_date_format(df, column_name):
    try:
        pd.to_datetime(df[column_name], format='%Y-%m-%d', errors='raise')
        return True  # The format is 'YYYY-MM-DD'
    except ValueError:
        return False  # The format is not 'YYYY-MM-DD'

# %%
if verify_date_format(df_sg, 'release_date'):
    print(f"The format of '{'release_date'}' is 'YYYY-MM-DD'")
else:
    print(f"The format of '{'release_date'}' is not 'YYYY-MM-DD'")

# %%
import pandas as pd
from dateutil import parser

def filter_dataframe_by_year_format(df, column_name):
    # Function to extract the year from various date formats
    def extract_year(date_str):
        try:
            parsed_date = parser.parse(str(date_str))
            return parsed_date.year
        except ValueError:
            return None

    # Apply the extract_year function to the specified column
    df['extracted_year'] = df['release_date'].apply(extract_year)

    # Filter rows with the correct 'YYYY-MM-DD' format or extracted year
    mask = (df['release_date'].astype(str).str.match(r'^\d{4}-\d{2}-\d{2}$')) | (~df['extracted_year'].isnull())

    # If you want to filter based on a specific year, you can modify the following line
    # For example, to filter for the year 2022, use: mask = mask & ((df['extracted_year'] == 2022) | (df[column_name].astype(str).str.match(r'^\d{4}-\d{2}-\d{2}$')))

    # Drop the temporary 'extracted_year' column
    df = df.drop(columns=['extracted_year'])

    filtered_df = df[mask]

    return filtered_df

# Example usage:
# Assuming df is your pandas DataFrame and 'date_column' is the column you want to filter
# Replace 'date_column' with the actual column name in your DataFrame
filtered_dataframe = filter_dataframe_by_year_format(df, 'date_column')

# %%
import pandas as pd
from dateutil import parser

def extract_years_from_column(df, column_name):
    # Function to extract the year from various date formats
    def extract_year(date_str):
        try:
            parsed_date = parser.parse(str(date_str))
            return parsed_date.year
        except ValueError:
            return None

    # Apply the extract_year function to the specified column
    df['extracted_year'] = df['release_date'].apply(extract_year)

    return df['extracted_year']

# Example usage:
# Assuming df is your pandas DataFrame and 'date_column' is the column you want to extract years from
# Replace 'date_column' with the actual column name in your DataFrame

# Extract years and create a mask for valid years
years_mask = extract_years_from_column(df_sg, 'release_date').notnull()

# Apply the mask to filter the DataFrame
filtered_dataframe = df_sg[years_mask]

# %%
filtered_dataframe.info()
filtered_dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 29893 entries, 88310 to 120443
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   publisher       23897 non-null  object
#  1   genres          28659 non-null  object
#  2   app_name        29892 non-null  object
#  3   title           29892 non-null  object
#  4   url             29893 non-null  object
#  5   release_date    29893 non-null  object
#  6   tags            29732 non-null  object
#  7   reviews_url     29893 non-null  object
#  8   specs           29224 non-null  object
#  9   price           28816 non-null  object
#  10  early_access    29893 non-null  float64
#  11  id              29893 non-null  float64
#  12  developer       28643 non-null  object
#  13  extracted_year  29893 non-null  float64
# dtypes: float64(3), object(11)
# memory usage: 3.4+ MB
#                   publisher  \
# 88310             Kotoshiro
# ...

# %%
import ast
import gzip
users_items_gz = "/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/users_items.json.gz"
filas=[]
with gzip.open(users_items_gz, 'rt', encoding='MacRoman') as archivo:
    for line in archivo.readlines():
        filas.append(ast.literal_eval(line))

df_ui = pd.DataFrame(filas)
df_ui = df_ui.explode('items').reset_index()
df_ui = df_ui.drop(columns="index")
df_ui = pd.concat([df_ui, pd.json_normalize(df_ui['items'])], axis=1)
df_ui = df_ui.drop(columns='items')

# %%
df_ui
# Out:
#                    user_id  items_count           steam_id  \
# 0        76561197970982479          277  76561197970982479
# 1        76561197970982479          277  76561197970982479
# 2        76561197970982479          277  76561197970982479
# 3        76561197970982479          277  76561197970982479
# 4        76561197970982479          277  76561197970982479
# ...                    ...          ...                ...
# 5170010  76561198329548331            7  76561198329548331
# 5170011  76561198329548331            7  76561198329548331
# 5170012  76561198329548331            7  76561198329548331
# 5170013  76561198329548331            7  76561198329548331
# 5170014  edward_tremethick            0  76561198331598578
#
#                                                   user_url item_id  \
# 0        http://steamcommunity.com/profiles/76561197970...      10
# 1        http://steamcommunity.com/profiles/76561197970...      20
# ...

# %%
#steam_proc['tags'] = steam_proc['tags'].apply(lambda x: [item for item in x if item in genres] if isinstance(x, list) else x)
#steam_proc.loc[valid_date_mask, 'Year'] = pd.to_datetime(steam_proc.loc[valid_date_mask, 'release_date'], errors='coerce').dt.year
#steam_proc['Year'] = steam_proc['Year'].astype(float)

# %%
import gzip
import json
import ast
import shutil

# %% [markdown]
# # Nueva sección

# %%
#df_ur=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz',orient='JsonSeriesOrient',lines = True,encoding='utf-8-sig')
#df_ur=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz',orient='split',lines = True,encoding='utf-8-sig')
user_reviews_gz = "/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz"
filas=[]
with gzip.open(user_reviews_gz, 'rt', encoding='MacRoman') as archivo:
    for line in archivo.readlines():
        filas.append(ast.literal_eval(line))

user_review = pd.DataFrame(filas)

# %%
user_review
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
#import ast as ast
#Asigno al DataFrame el archivo json user_reviews.json.gz
#df_ur=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz',orient='JsonSeriesOrient',lines = True,encoding='utf-8-sig')
#df_ur=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz',lines = False,encoding='utf-8-sig')

#archivo = '/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz'
#lista para guardar cada fila
#lista = []
#with open(archivo, encoding='utf-8') as file:
#    for line in file.readlines():
#        lista.append(ast.literal_eval(line))

#def abrir_json_comprimido(ruta_archivo):
#	with gzip.open(ruta_archivo,'rt',encoding='utf-8') as archivo_comprimido:
#		contenido_json=json.load(archivo_comprimido)
#	return contenido_json
#Ejemplo de uso
#ruta_archivo = '/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz'
#contenido= abrir_json_comprimido(ruta_archivo)

#Ahora puedes trabajar con el contenido como un diccionario de Python
#print(contenido)

# Descomprimo los archivos

# Ruta al archivo comprimido
ruta_comprimida_ur= '/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/user_reviews.json.gz'

# Ruta para guardar temporalmente el archivo descomprimido en Colab
ruta_temporal_ur = '/content/user_reviews.json'

# Descomprimir el archivo
with gzip.open(ruta_comprimida_ur, 'rb') as f_in:
    with open(ruta_temporal_ur, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
# Guardo en una variable el archivo
data_ur = '/content/user_reviews.json'

# Cargo archivo JSON línea por línea y almaceno en una lista.

# Lista para guardar cada fila
lista_ur = []

with open(data_ur, encoding='utf-8') as file:
    for line in file.readlines():
            lista_ur.append(ast.literal_eval(line))

# Guardo el archivo en un DataFrame
df_ur = pd.DataFrame(lista_ur)
df_ur.head(5)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...

# %%
#Visualizo el DataFrame
df_ur
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %%
users_items_gz = "/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/users_items.json.gz"
filas=[]
with gzip.open(users_items_gz, 'rt', encoding='MacRoman') as archivo:
    for line in archivo.readlines():
        filas.append(ast.literal_eval(line))

users_items = pd.DataFrame(filas)

# %%
users_items
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# ...

# %%
users_items['items'][0][1]
# Out:
# {'item_id': '20',
#  'item_name': 'Team Fortress Classic',
#  'playtime_forever': 0,
#  'playtime_2weeks': 0}

# %%
max_playtime_items = user_rev_item.groupby('user_id')['playtime_forever'].idxmax()

# %%
#Asigno al DataFrame el archivo json users_items.json.gz
#df_ui=pd.read_json('/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/users_items.json.gz',lines=True)

# Ruta al archivo comprimido
ruta_comprimida_ui= '/content/drive/MyDrive/PI_ML_OPS-PT/Dataset/users_items.json.gz'

# Ruta para guardar temporalmente el archivo descomprimido en Colab
ruta_temporal_ui = '/content/users_items.json'

# Descomprimir el archivo
with gzip.open(ruta_comprimida_ui, 'rb') as f_in:
    with open(ruta_temporal_ui, 'wb') as f_out:
            shutil.copyfileobj(f_in, f_out)
# Guardo en una variable el archivo
data_ui = '/content/users_items.json'

# Cargo archivo JSON línea por línea y almaceno en una lista.

# Lista para guardar cada fila
lista_ui = []

with open(data_ui, encoding='utf-8') as file:
    for line in file.readlines():
            lista_ui.append(ast.literal_eval(line))

# Guardo el archivo en un DataFrame
df_ui = pd.DataFrame(lista_ur)
df_ui.head(5)
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1            js41637               http://steamcommunity.com/id/js41637
# 2          evcentric             http://steamcommunity.com/id/evcentric
# 3              doctr                 http://steamcommunity.com/id/doctr
# 4          maplemage             http://steamcommunity.com/id/maplemage
#
#                                              reviews
# 0  [{'funny': '', 'posted': 'Posted November 5, 2...
# 1  [{'funny': '', 'posted': 'Posted June 24, 2014...
# 2  [{'funny': '', 'posted': 'Posted February 3.',...
# 3  [{'funny': '', 'posted': 'Posted October 14, 2...
# 4  [{'funny': '3 people found this review funny',...
